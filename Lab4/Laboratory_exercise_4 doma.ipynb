# %% [markdown]
# # Laboratory exercise 4
#
# ## Warm-Up Mode (2 points)
#
# **Task Description**
# Using the given dataset, develop and implement **3** different neural networks to predict the **air quality level**. Each network should differ in the following ways:
#
# - **layer configurations** - use different numbers and types of layers;
# - **activation functions** - try different activation functions;
# - **neurons per layer** - experiment with different numbers of neurons in each layer; and
# - **number of layers** - build networks with varying depths.
#
# After developing the models, evaluate and compare the performance of all **3** approaches.
#
# **About the Dataset**
# This dataset focuses on air quality assessment across various regions. The dataset contains 5,000 samples and captures critical environmental and demographic factors that influence pollution levels.
#
# **Features**:
# - **Temperature (°C)**: Average temperature of the region.
# - **Humidity (%)**: Relative humidity recorded in the region.
# - **PM2.5 Concentration (µg/m³)**: Levels of fine particulate matter.
# - **PM10 Concentration (µg/m³)**: Levels of coarse particulate matter.
# - **NO2 Concentration (ppb)**: Nitrogen dioxide levels.
# - **SO2 Concentration (ppb)**: Sulfur dioxide levels.
# - **CO Concentration (ppm)**: Carbon monoxide levels.
# - **Proximity to Industrial Areas (km)**: Distance to the nearest industrial zone.
# - **Population Density (people/km²)**: Number of people per square kilometer in the region.
#
# **Target Variable**: **Air Quality**
# - **Good**: Clean air with low pollution levels.
# - **Moderate**: Acceptable air quality but with some pollutants present.
# - **Poor**: Noticeable pollution that may cause health issues for sensitive groups.
# - **Hazardous**: Highly polluted air posing serious health risks to the population.

# %%
import pandas as pd

# %%
data =  pd.read_csv('pollution_dataset.csv')

# %%
data.head()
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# 4                           12.7                 303        Good

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 390.8+ KB

# %%
missing_percent = data.isnull().sum() / len(data) * 100
missing_percent
# Out:
# Temperature                      0.0
# Humidity                         0.0
# PM2.5                            0.0
# PM10                             0.0
# NO2                              0.0
# SO2                              0.0
# CO                               0.0
# Proximity_to_Industrial_Areas    0.0
# Population_Density               0.0
# Air Quality                      0.0
# dtype: float64

# %%
data['Air Quality'].unique()
# Out:
# array(['Moderate', 'Good', 'Hazardous', 'Poor'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

data['Air Quality'] = encoder.fit_transform(data[['Air Quality']])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 390.8 KB

# %%
x, y = data.drop('Air Quality', axis=1), data['Air Quality']

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=False)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import classification_report

# %%
model1 = Sequential()
model1.add(Dense(32, activation='relu'))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(4, activation='softmax'))

# %%
model1.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model1.fit(train_x, train_y, validation_split=0.2, epochs=20, batch_size=8)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3432 - loss: 7.2016 - val_accuracy: 0.6637 - val_loss: 0.8615
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6429 - loss: 0.8617 - val_accuracy: 0.6775 - val_loss: 0.7110
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6544 - loss: 0.7569 - val_accuracy: 0.6438 - val_loss: 0.7208
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6386 - loss: 0.7342 - val_accuracy: 0.6637 - val_loss: 0.6616
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6649 - loss: 0.6913 - val_accuracy: 0.7025 - val_loss: 0.6484
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6813 - loss: 0.6688 - val_accuracy: 0.7825 - val_loss: 0.6309
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6420 - loss: 0.7239 - val_accuracy: 0.7013 - val_loss: 0.8081
# Epoch 8/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6987 - loss: 0.7005 - val_accuracy: 0.6637 - val_loss: 0.6796
# Epoch 9/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6997 - loss: 0.6556 - val_accuracy: 0.6575 - val_loss: 0.6934
# Epoch 10/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6333 - loss: 0.7475 - val_accuracy: 0.7688 - val_loss: 0.6190
# Epoch 11/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7561 - loss: 0.6354 - val_accuracy: 0.7837 - val_loss: 0.5736
# Epoch 12/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7481 - loss: 0.6212 - val_accuracy: 0.6900 - val_loss: 0.6323
# Epoch 13/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7581 - loss: 0.5966 - val_accuracy: 0.7225 - val_loss: 0.7574
# Epoch 14/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7720 - loss: 0.5948 - val_accuracy: 0.7887 - val_loss: 0.5219
# Epoch 15/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7659 - loss: 0.5531 - val_accuracy: 0.7912 - val_loss: 0.5004
# Epoch 16/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7676 - loss: 0.5842 - val_accuracy: 0.7462 - val_loss: 0.5593
# Epoch 17/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7723 - loss: 0.5132 - val_accuracy: 0.7487 - val_loss: 0.5409
# Epoch 18/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7996 - loss: 0.4664 - val_accuracy: 0.8650 - val_loss: 0.4150
# Epoch 19/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8512 - loss: 0.4150 - val_accuracy: 0.8963 - val_loss: 0.3877
# Epoch 20/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8284 - loss: 0.4245 - val_accuracy: 0.8587 - val_loss: 0.4196

# %%
model2 = Sequential()
model2.add(Dense(32, activation='tanh'))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(4, activation='softmax'))
model2.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model2.fit(train_x, train_y, validation_split=0.2, epochs=20, batch_size=8)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3617 - loss: 1.3161 - val_accuracy: 0.3938 - val_loss: 1.2812
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3948 - loss: 1.2910 - val_accuracy: 0.3938 - val_loss: 1.2804
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4051 - loss: 1.2706 - val_accuracy: 0.3938 - val_loss: 1.2811
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3957 - loss: 1.2905 - val_accuracy: 0.3938 - val_loss: 1.2789
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3919 - loss: 1.3007 - val_accuracy: 0.3938 - val_loss: 1.2796
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4102 - loss: 1.2717 - val_accuracy: 0.3938 - val_loss: 1.2811
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3980 - loss: 1.2846 - val_accuracy: 0.3938 - val_loss: 1.2793
# Epoch 8/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3994 - loss: 1.2902 - val_accuracy: 0.3938 - val_loss: 1.2792
# Epoch 9/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4044 - loss: 1.2744 - val_accuracy: 0.3938 - val_loss: 1.2823
# Epoch 10/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4003 - loss: 1.2853 - val_accuracy: 0.3938 - val_loss: 1.2797
# Epoch 11/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3966 - loss: 1.2903 - val_accuracy: 0.3938 - val_loss: 1.2802
# Epoch 12/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4076 - loss: 1.2732 - val_accuracy: 0.3938 - val_loss: 1.2790
# Epoch 13/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.3954 - loss: 1.2846 - val_accuracy: 0.3938 - val_loss: 1.2794
# Epoch 14/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3956 - loss: 1.2798 - val_accuracy: 0.3938 - val_loss: 1.2811
# Epoch 15/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3936 - loss: 1.2790 - val_accuracy: 0.3938 - val_loss: 1.2809
# Epoch 16/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3975 - loss: 1.2845 - val_accuracy: 0.3938 - val_loss: 1.2798
# Epoch 17/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3852 - loss: 1.2915 - val_accuracy: 0.3938 - val_loss: 1.2791
# Epoch 18/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4027 - loss: 1.2753 - val_accuracy: 0.3938 - val_loss: 1.2801
# Epoch 19/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3910 - loss: 1.2935 - val_accuracy: 0.3938 - val_loss: 1.2795
# Epoch 20/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4057 - loss: 1.2767 - val_accuracy: 0.3938 - val_loss: 1.2796

# %%
model3 = Sequential()
model3.add(Dense(128, activation='relu'))
model3.add(Dense(64, activation='relu'))
model3.add(Dense(32, activation='relu'))
model3.add(Dense(16, activation='relu'))
model3.add(Dense(4, activation='softmax'))
model3.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model3.fit(train_x, train_y, validation_split=0.2, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3587 - loss: 13.5517 - val_accuracy: 0.5800 - val_loss: 0.8707
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6444 - loss: 0.8225 - val_accuracy: 0.7175 - val_loss: 0.6734
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6740 - loss: 0.7437 - val_accuracy: 0.7088 - val_loss: 0.6184
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7661 - loss: 0.5728 - val_accuracy: 0.7950 - val_loss: 0.5062
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7614 - loss: 0.5462 - val_accuracy: 0.7912 - val_loss: 0.5316
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7920 - loss: 0.4920 - val_accuracy: 0.7763 - val_loss: 0.5719
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7820 - loss: 0.5111 - val_accuracy: 0.8050 - val_loss: 0.4720
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8256 - loss: 0.4379 - val_accuracy: 0.8350 - val_loss: 0.4167
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8162 - loss: 0.4411 - val_accuracy: 0.7538 - val_loss: 0.6256
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7888 - loss: 0.5168 - val_accuracy: 0.8275 - val_loss: 0.4339
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8325 - loss: 0.4350 - val_accuracy: 0.7312 - val_loss: 0.5751
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8237 - loss: 0.4332 - val_accuracy: 0.8612 - val_loss: 0.3886
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8399 - loss: 0.4131 - val_accuracy: 0.8525 - val_loss: 0.3932
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8364 - loss: 0.4108 - val_accuracy: 0.8475 - val_loss: 0.3863
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8494 - loss: 0.3751 - val_accuracy: 0.8625 - val_loss: 0.3769
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8458 - loss: 0.3976 - val_accuracy: 0.8687 - val_loss: 0.3775
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8531 - loss: 0.3713 - val_accuracy: 0.8587 - val_loss: 0.3992
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8517 - loss: 0.3662 - val_accuracy: 0.8587 - val_loss: 0.4106
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8413 - loss: 0.3954 - val_accuracy: 0.7487 - val_loss: 0.5273
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8604 - loss: 0.3740 - val_accuracy: 0.7937 - val_loss: 0.4691

# %%
print(f'Model 1 accuracy: {model1.evaluate(test_x, test_y, verbose=0)[1]}')
print(f'Model 2 accuracy: {model2.evaluate(test_x, test_y, verbose=0)[1]}')
print(f'Model 3 accuracy: {model3.evaluate(test_x, test_y, verbose=0)[1]}')
# Out:
# Model 1 accuracy: 0.8650000095367432
# Model 2 accuracy: 0.41100001335144043
# Model 3 accuracy: 0.7879999876022339

# %%
import numpy as np

# %%
pred_y1 = np.argmax(model1.predict(test_x).round(), axis=1)
pred_y2 = np.argmax(model2.predict(test_x).round(), axis=1)
pred_y3 = np.argmax(model3.predict(test_x).round(), axis=1)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print(classification_report(test_y, pred_y1))
print(classification_report(test_y, pred_y2))
print(classification_report(test_y, pred_y3))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94       411
#          1.0       1.00      0.50      0.67       104
#          2.0       0.78      0.98      0.87       300
#          3.0       0.74      0.55      0.63       185
#
#     accuracy                           0.84      1000
#    macro avg       0.86      0.75      0.78      1000
# weighted avg       0.85      0.84      0.83      1000
#
#               precision    recall  f1-score   support
#
#          0.0       0.41      1.00      0.58       411
#          1.0       0.00      0.00      0.00       104
#          2.0       0.00      0.00      0.00       300
#          3.0       0.00      0.00      0.00       185
#
#     accuracy                           0.41      1000
#    macro avg       0.10      0.25      0.15      1000
# weighted avg       0.17      0.41      0.24      1000
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       411
#          1.0       0.89      0.62      0.73       104
#          2.0       0.80      0.59      0.68       300
#          3.0       0.53      0.90      0.66       185
#
#     accuracy                           0.79      1000
#    macro avg       0.80      0.76      0.76      1000
# weighted avg       0.83      0.79      0.79      1000
# D:\Miniconda\envs\env2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\Miniconda\envs\env2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\Miniconda\envs\env2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
